# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import difflib
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

from sklearn.linear_model import LogisticRegression as LR

# %%
dems = pd.read_csv('../datasets/dem_candidates.csv')
fec = pd.read_csv('../datasets/fec-house.csv')
brookings = pd.read_csv('../datasets/brookings.csv')
brookings538 = pd.read_csv('../datasets/joined_dfs.csv')

# %%
def count_candidates_by_district(df, district_column, new_column_name):
    """
    Adds a column to the DataFrame with the count of candidates in each district.

    Parameters:
    df (pd.DataFrame): The DataFrame containing the candidates and districts.
    district_column (str): The name of the column with district information.
    new_column_name (str): The name of the new column to hold the counts.

    Returns:
    pd.DataFrame: The original DataFrame with an additional column for candidate counts per district.
    """
    # Calculate the number of candidates in each district
    district_counts = df.groupby(district_column).size().reset_index(name=new_column_name)
    
    # Merge the counts back into the original DataFrame
    df_merged = df.merge(district_counts, on=district_column)

    return df_merged

# %%
dems = count_candidates_by_district(dems, 'District', 'total_runners') #run the above func to get count of ppl in each race and add that as a new col
dems = dems[dems['total_runners'] > 1] # filter out all the rows where only 1 person ran. 
dems = dems[dems['Race Type'] == 'Regular'] # filter out all special races due to repetitions and different circumstances
dems = dems[dems['Office Type'] == 'Representative'] #just house

dems = dems.rename(columns={'Warren Endorsed? ': 'Warren Endorsed?', 'Guns Sense Candidate?': 'Gun Sense Candidate?'})
endorsement_cols = dems.columns[pd.Series(dems.columns).str.contains('Endorsed')].values
endorsement_cols = np.append(endorsement_cols, 'Gun Sense Candidate?')
endorsement_cols = np.append(endorsement_cols, 'Party Support?')
# endorsement_cols = np.append(endorsement_cols, 'No Labels Support?')
dems[endorsement_cols] = dems[endorsement_cols].replace({'No': 0, 'Yes': 1})
dems['Total Endorsements'] = dems[endorsement_cols].sum(axis=1)
dems['Endorsed'] = (dems['Total Endorsements'] > 0).astype(int)

dems['Won Primary'] = (dems['Won Primary'] == 'Yes').astype(int)
dems['Primary Status'] = (dems['Primary Status'] == 'Advanced').astype(int) # same as Won Primary but no missing values

dems['Race'] = (dems['Race'] == 'Nonwhite').astype(int)
dems['Veteran?'] = (dems['Veteran?'] == 'Yes').astype(int)
dems['LGBTQ?'] = (dems['LGBTQ?'] == 'Yes').astype(int)
dems['Self-Funder?'] = (dems['Self-Funder?'] == 'Yes').astype(int)
dems['STEM?'] = (dems['STEM?'] == 'Yes').astype(int)
dems['Elected Official?'] = (dems['Elected Official?'] == 'Yes').astype(int)

dems = dems.reset_index().drop(columns=['index'])

# %%
dems.head()
# Out:
#                  Candidate State                       District  \
# 0  Lizzetta Hill McConnell    AL  U.S. House Alabama District 1
# 1       Robert Kennedy Jr.    AL  U.S. House Alabama District 1
# 2     Audri Scott Williams    AL  U.S. House Alabama District 2
# 3            Tabitha Isner    AL  U.S. House Alabama District 2
# 4   Adia McClellan Winfrey    AL  U.S. House Alabama District 3
#
#       Office Type Race Type Race Primary Election Date  Primary Status  \
# 0  Representative   Regular                     6/5/18               0
# 1  Representative   Regular                     6/5/18               1
# 2  Representative   Regular                     6/5/18               0
# 3  Representative   Regular                     6/5/18               1
# 4  Representative   Regular                     6/5/18               0
#
#   Primary Runoff Status General Status  Partisan Lean  ...  \
# 0                  None           None     -30.680000  ...
# 1                  None  On the Ballot     -30.680000  ...
# 2                  None           None     -33.080002  ...
# 3                  None  On the Ballot     -33.080002  ...
# 4                  None           None     -33.660000  ...
#
#    Our Revolution Endorsed?  Justice Dems Endorsed?  PCCC Endorsed?  \
# 0                       NaN                     NaN             NaN
# 1                       NaN                     NaN             NaN
# 2                       NaN                     NaN             NaN
# 3                       NaN                     NaN             NaN
# 4                       NaN                     NaN             NaN
#
#    Indivisible Endorsed?  WFP Endorsed?  VoteVets Endorsed?  \
# 0                    NaN            NaN                 NaN
# 1                    NaN            NaN                 NaN
# 2                    NaN            NaN                 NaN
# 3                    NaN            NaN                 NaN
# 4                    NaN            NaN                 NaN
#
#    No Labels Support?  total_runners Total Endorsements  Endorsed
# 0                 NaN              2                0.0         0
# 1                 NaN              2                0.0         0
# 2                 NaN              2                0.0         0
# 3                 NaN              2                0.0         0
# 4                 NaN              2                1.0         1
#
# [5 rows x 35 columns]

# %%
dems.columns
# Out:
# Index(['Candidate', 'State', 'District', 'Office Type', 'Race Type',
#        'Race Primary Election Date', 'Primary Status', 'Primary Runoff Status',
#        'General Status', 'Partisan Lean', 'Primary %', 'Won Primary', 'Race',
#        'Veteran?', 'LGBTQ?', 'Elected Official?', 'Self-Funder?', 'STEM?',
#        'Obama Alum?', 'Party Support?', 'Emily Endorsed?',
#        'Gun Sense Candidate?', 'Biden Endorsed?', 'Warren Endorsed?',
#        'Sanders Endorsed?', 'Our Revolution Endorsed?',
#        'Justice Dems Endorsed?', 'PCCC Endorsed?', 'Indivisible Endorsed?',
#        'WFP Endorsed?', 'VoteVets Endorsed?', 'No Labels Support?',
#        'total_runners', 'Total Endorsements', 'Endorsed'],
#       dtype='object')

# %% [markdown]
# Justice Dems (50), Our Revolution (85), WFP (30), Indivisible (46), VoteVets (28), Emily (54), PCCC (15), Party (39), Gun Sense (193)

# %%
endorsement_cols
# Out:
# array(['Emily Endorsed?', 'Biden Endorsed?', 'Warren Endorsed?',
#        'Sanders Endorsed?', 'Our Revolution Endorsed?',
#        'Justice Dems Endorsed?', 'PCCC Endorsed?',
#        'Indivisible Endorsed?', 'WFP Endorsed?', 'VoteVets Endorsed?',
#        'Gun Sense Candidate?', 'Party Support?'], dtype=object)

# %%
fec.head()
# Out:
#                name office office_full party        party_full state  \
# 0  SEWELL, TERRI A.      H       House   DEM  DEMOCRATIC PARTY    AL
# 1     BERA, AMERISH      H       House   DEM  DEMOCRATIC PARTY    CA
# 2  DESAULNIER, MARK      H       House   DEM  DEMOCRATIC PARTY    CA
# 3   GARAMENDI, JOHN      H       House   DEM  DEMOCRATIC PARTY    CA
# 4      SCHIFF, ADAM      H       House   DEM  DEMOCRATIC PARTY    CA
#
#    district  district_number                        election_districts  \
# 0         7                7                 {07,07,07,07,07,07,07,07}
# 1         7                7                 {03,07,07,07,07,07,06,06}
# 2        11               11                    {10,11,11,11,11,10,10}
# 3         3                3                 {10,03,03,03,03,03,08,08}
# 4        28               28  {27,29,29,29,29,29,28,28,28,28,28,30,30}
#
#                                       election_years  ... party.1 office.1  \
# 0          {2010,2012,2014,2016,2018,2020,2022,2024}  ...     DEM        H
# 1          {2010,2012,2014,2016,2018,2020,2022,2024}  ...     DEM        H
# 2               {2010,2014,2016,2018,2020,2022,2024}  ...     DEM        H
# 3          {2010,2012,2014,2016,2018,2020,2022,2024}  ...     DEM        H
# 4  {2000,2002,2004,2006,2008,2010,2012,2014,2016,...  ...     DEM        H
#
#   candidate_inactive.1 individual_itemized_contributions  \
# 0                    f                         314433.51
# 1                    f                        1463699.25
# 2                    f                         177938.55
# 3                    f                         346985.92
# 4                    f                        2955743.08
#
#   transfers_from_other_authorized_committee  \
# 0                                      0.00
# 1                                      0.00
# 2                                      0.00
# 3                                      0.00
# 4                                 722929.86
#
#   other_political_committee_contributions state.1 district.1  \
# 0                              1453045.73      AL          7
# 1                              1193555.00      CA          7
# 2                               344100.00      CA         11
# 3                               712960.30      CA          3
# 4                               566750.00      CA         28
#
#   district_number.1  state_full
# 0                 7     Alabama
# 1                 7  California
# 2                11  California
# 3                 3  California
# 4                28  California
#
# [5 rows x 50 columns]

# %%
fec.columns
# Out:
# Index(['name', 'office', 'office_full', 'party', 'party_full', 'state',
#        'district', 'district_number', 'election_districts', 'election_years',
#        'cycles', 'candidate_status', 'incumbent_challenge',
#        'incumbent_challenge_full', 'load_date', 'first_file_date',
#        'last_file_date', 'last_f2_date', 'candidate_id', 'two_year_period',
#        'candidate_election_year', 'address_city', 'address_state',
#        'address_street_1', 'address_street_2', 'address_zip',
#        'candidate_inactive', 'active_through', 'candidate_id.1',
#        'election_year', 'cycle', 'is_election', 'receipts', 'disbursements',
#        'cash_on_hand_end_period', 'debts_owed_by_committee',
#        'coverage_start_date', 'coverage_end_date', 'federal_funds_flag',
#        'has_raised_funds', 'party.1', 'office.1', 'candidate_inactive.1',
#        'individual_itemized_contributions',
#        'transfers_from_other_authorized_committee',
#        'other_political_committee_contributions', 'state.1', 'district.1',
#        'district_number.1', 'state_full'],
#       dtype='object')

# %%
def fuzzy_merge(df_1, df_2, key1, key2, threshold=80, limit=2):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with boths keys and matches
    """
    s = df_2[key2].str.extract('([\w\s]*)')[0].tolist()
    
    m = df_1[key1].apply(lambda x: process.extractOne(x, s, scorer=fuzz.token_sort_ratio, score_cutoff=threshold))    
    df_1['matches'] = m.str[0]
    
    return df_1

# %%
dems['first'] = dems['Candidate'].str.lower().str.split(' ', n=1, expand=True)[0]
lastnames = dems['Candidate'].str.lower().str.split(' ', n=1, expand=True)[1].str.findall('^([a-z]*)$|(?<=[\s\t])(\w+\-*)$|^(\w+\-*)(?=[\s\t])').str[-1].astype(str).str.extract('(\w+)')
dems['last'] = lastnames[0]
dems['firstlast'] = dems['first'] + ' ' + dems['last']

fec['first'] = fec['name'].str.lower().str.extract(', (\w+\s*\w+)')[0]
fec['last'] = fec['name'].str.lower().str.extract('(\w+\s*\w+)')[0]
fec['firstlast'] = fec['first'] + ' ' + fec['last']

# %%
# manually correcting matching errors
matches = fuzzy_merge(dems, fec, 'Candidate', 'firstlast', threshold=60, limit=1)
matches.loc[19, 'matches'] = 'michael james barkley'
matches.loc[63, 'matches'] = 'jeffrey malloy'
matches.loc[68, 'matches'] = 'mark joaquin williams'
matches.loc[83, 'matches'] = 'michael nesmith'
matches.loc[84, 'matches'] = 'charles joseph enderlin'
matches.loc[85, 'matches'] = 'melvin russell oliver'
matches.loc[97, 'matches'] = 'joshua braxton mccall'
matches.loc[110, 'matches'] = 'michael william smith'
matches.loc[117, 'matches'] = 'david michael gill'
matches.loc[156, 'matches'] = 'joseph william mackey'
matches.loc[169, 'matches'] = 'joshua alexander williamson'
matches.loc[170, 'matches'] = 'kenneth j lave'
matches.loc[198, 'matches'] = 'reginald leonard thomas'
matches.loc[203, 'matches'] = 'michael bernard brown'
matches.loc[225, 'matches'] = 'william r wild'
matches.loc[227, 'matches'] = 'coleman alexander young'
matches.loc[232, 'matches'] = 'weldon frederick wooden'
matches.loc[241, 'matches'] = 'christopher e smith'
matches.loc[246, 'matches'] = 'william c haas'
matches.loc[285, 'matches'] = 'fernando cano'
matches = matches.drop(index=[315]).reset_index().drop(columns=['index'])
matches.loc[320, 'matches'] = 'john dennis love'
matches.loc[432, 'matches'] = 'eric feigl'
matches.loc[475, 'matches'] = 'brandon pendarvis brown'
matches.loc[478, 'matches'] = 'john timothy davis'
matches.loc[481, 'matches'] = 'mark anthony ali'
matches.loc[483, 'matches'] = 'stephen harrison lough'
matches.loc[484, 'matches'] = 'william e hopkins'
matches.loc[505, 'matches'] = 'madeline katherine eden'
matches.loc[511, 'matches'] = 'virginia louise leeder'
matches.loc[535, 'matches'] = 'stephen keith brown ii'
matches.loc[543, 'matches'] = 'joshua andrew imhoff'
matches.loc[544, 'matches'] = 'edward allen'
matches.loc[546, 'matches'] = 'christopher michael perri'
matches.loc[593, 'matches'] = 'elizabeth fletcher'
matches.loc[594, 'matches'] = 'kut frederick weiland'

# %%
matches
# Out:
#                    Candidate State                             District  \
# 0    Lizzetta Hill McConnell    AL        U.S. House Alabama District 1
# 1         Robert Kennedy Jr.    AL        U.S. House Alabama District 1
# 2       Audri Scott Williams    AL        U.S. House Alabama District 2
# 3              Tabitha Isner    AL        U.S. House Alabama District 2
# 4     Adia McClellan Winfrey    AL        U.S. House Alabama District 3
# ..                       ...   ...                                  ...
# 627           Talley Sergent    WV  U.S. House West Virginia District 2
# 628          Janice Hagerman    WV  U.S. House West Virginia District 3
# 629               Paul Davis    WV  U.S. House West Virginia District 3
# 630            Richard Ojeda    WV  U.S. House West Virginia District 3
# 631             Shirley Love    WV  U.S. House West Virginia District 3
#
#         Office Type Race Type Race Primary Election Date  Primary Status  \
# 0    Representative   Regular                     6/5/18               0
# 1    Representative   Regular                     6/5/18               1
# 2    Representative   Regular                     6/5/18               0
# 3    Representative   Regular                     6/5/18               1
# 4    Representative   Regular                     6/5/18               0
# ..              ...       ...                        ...             ...
# 627  Representative   Regular                     5/8/18               1
# 628  Representative   Regular                     5/8/18               0
# 629  Representative   Regular                     5/8/18               0
# 630  Representative   Regular                     5/8/18               1
# 631  Representative   Regular                     5/8/18               0
#
#     Primary Runoff Status General Status  Partisan Lean  ...  WFP Endorsed?  \
# 0                    None           None     -30.680000  ...            NaN
# 1                    None  On the Ballot     -30.680000  ...            NaN
# 2                    None           None     -33.080002  ...            NaN
# 3                    None  On the Ballot     -33.080002  ...            NaN
# 4                    None           None     -33.660000  ...            NaN
# ..                    ...            ...            ...  ...            ...
# 627                  None  On the Ballot     -35.330002  ...            NaN
# 628                  None           None     -47.480000  ...            0.0
# 629                  None           None     -47.480000  ...            0.0
# 630                  None  On the Ballot     -47.480000  ...            1.0
# 631                  None           None     -47.480000  ...            0.0
#
#      VoteVets Endorsed?  No Labels Support?  total_runners  \
# 0                   NaN                 NaN              2
# 1                   NaN                 NaN              2
# 2                   NaN                 NaN              2
# 3                   NaN                 NaN              2
# 4                   NaN                 NaN              2
# ..                  ...                 ...            ...
# 627                 0.0                 NaN              2
# 628                 0.0                 NaN              4
# 629                 0.0                 NaN              4
# 630                 1.0                 NaN              4
# 631                 0.0                 NaN              4
#
#      Total Endorsements  Endorsed     first       last           firstlast  \
# 0                   0.0         0  lizzetta  mcconnell  lizzetta mcconnell
# 1                   0.0         0    robert    kennedy      robert kennedy
# 2                   0.0         0     audri   williams      audri williams
# 3                   0.0         0   tabitha      isner       tabitha isner
# 4                   1.0         1      adia    winfrey        adia winfrey
# ..                  ...       ...       ...        ...                 ...
# 627                 0.0         0    talley    sergent      talley sergent
# 628                 0.0         0    janice   hagerman     janice hagerman
# 629                 0.0         0      paul      davis          paul davis
# 630                 2.0         1   richard      ojeda       richard ojeda
# 631                 0.0         0   shirley       love        shirley love
#
#                      matches
# 0    lizzetta hill mcconnell
# 1          robert jr kennedy
# 2       audri scott williams
# 3          tabitha kay isner
# 4     adia mcclellan winfrey
# ..                       ...
# 627           talley sergent
# 628          janice hagerman
# 629             paul t davis
# 630      richard neece ojeda
# 631             shirley love
#
# [632 rows x 39 columns]

# %%
merged = pd.merge(matches.drop(columns=['first', 'last', 'firstlast']), fec.drop(columns=['first', 'last']), how='left', 
        left_on='matches', right_on='firstlast').drop(columns=['office_full', 'party', 'party_full', 'state', 'district',
       'district_number', 'election_districts', 'election_years', 'cycles', 
       'candidate_status', 'incumbent_challenge', 'incumbent_challenge_full',
       'load_date', 'address_city', 'first_file_date', 'last_file_date', 'last_f2_date', 
       'candidate_id', 'two_year_period', 'candidate_election_year', 'address_state', 
       'address_street_1', 'address_street_2', 'candidate_inactive', 'active_through', 
       'disbursements', 'cash_on_hand_end_period', 'debts_owed_by_committee',
       'individual_itemized_contributions', 'office', 'address_zip', 'name', 'matches', 
       'transfers_from_other_authorized_committee',
       'other_political_committee_contributions', 'firstlast',
       'candidate_id.1', 'election_year', 'cycle', 'is_election', 'coverage_start_date', 'coverage_end_date', 
       'federal_funds_flag', 'has_raised_funds', 'party.1', 'office.1', 'candidate_inactive.1', 'state.1', 
       'district.1', 'district_number.1', 'state_full'])
merged = merged[merged['Office Type'] == 'Representative']
merged
# Out:
#                    Candidate State                             District  \
# 0    Lizzetta Hill McConnell    AL        U.S. House Alabama District 1
# 1         Robert Kennedy Jr.    AL        U.S. House Alabama District 1
# 2       Audri Scott Williams    AL        U.S. House Alabama District 2
# 3              Tabitha Isner    AL        U.S. House Alabama District 2
# 4     Adia McClellan Winfrey    AL        U.S. House Alabama District 3
# ..                       ...   ...                                  ...
# 628           Talley Sergent    WV  U.S. House West Virginia District 2
# 629          Janice Hagerman    WV  U.S. House West Virginia District 3
# 630               Paul Davis    WV  U.S. House West Virginia District 3
# 631            Richard Ojeda    WV  U.S. House West Virginia District 3
# 632             Shirley Love    WV  U.S. House West Virginia District 3
#
#         Office Type Race Type Race Primary Election Date  Primary Status  \
# 0    Representative   Regular                     6/5/18               0
# 1    Representative   Regular                     6/5/18               1
# 2    Representative   Regular                     6/5/18               0
# 3    Representative   Regular                     6/5/18               1
# 4    Representative   Regular                     6/5/18               0
# ..              ...       ...                        ...             ...
# 628  Representative   Regular                     5/8/18               1
# 629  Representative   Regular                     5/8/18               0
# 630  Representative   Regular                     5/8/18               0
# 631  Representative   Regular                     5/8/18               1
# 632  Representative   Regular                     5/8/18               0
#
#     Primary Runoff Status General Status  Partisan Lean  ...  \
# 0                    None           None     -30.680000  ...
# 1                    None  On the Ballot     -30.680000  ...
# 2                    None           None     -33.080002  ...
# 3                    None  On the Ballot     -33.080002  ...
# 4                    None           None     -33.660000  ...
# ..                    ...            ...            ...  ...
# 628                  None  On the Ballot     -35.330002  ...
# 629                  None           None     -47.480000  ...
# 630                  None           None     -47.480000  ...
# 631                  None  On the Ballot     -47.480000  ...
# 632                  None           None     -47.480000  ...
#
#      Justice Dems Endorsed?  PCCC Endorsed?  Indivisible Endorsed?  \
# 0                       NaN             NaN                    NaN
# 1                       NaN             NaN                    NaN
# 2                       NaN             NaN                    NaN
# 3                       NaN             NaN                    NaN
# 4                       NaN             NaN                    NaN
# ..                      ...             ...                    ...
# 628                     NaN             NaN                    NaN
# 629                     NaN             NaN                    NaN
# 630                     NaN             NaN                    NaN
# 631                     NaN             NaN                    NaN
# 632                     NaN             NaN                    NaN
#
#      WFP Endorsed?  VoteVets Endorsed?  No Labels Support?  total_runners  \
# 0              NaN                 NaN                 NaN              2
# 1              NaN                 NaN                 NaN              2
# 2              NaN                 NaN                 NaN              2
# 3              NaN                 NaN                 NaN              2
# 4              NaN                 NaN                 NaN              2
# ..             ...                 ...                 ...            ...
# 628            NaN                 0.0                 NaN              2
# 629            0.0                 0.0                 NaN              4
# 630            0.0                 0.0                 NaN              4
# 631            1.0                 1.0                 NaN              4
# 632            0.0                 0.0                 NaN              4
#
#      Total Endorsements Endorsed    receipts
# 0                   0.0        0     5127.00
# 1                   0.0        0   166845.21
# 2                   0.0        0    35365.02
# 3                   0.0        0   524941.35
# 4                   1.0        1    14535.25
# ..                  ...      ...         ...
# 628                 0.0        0   705197.45
# 629                 0.0        0        0.00
# 630                 0.0        0  3985402.56
# 631                 2.0        1  2851527.56
# 632                 0.0        0    64000.00
#
# [633 rows x 36 columns]

# %%
merged.columns
# Out:
# Index(['Candidate', 'State', 'District', 'Office Type', 'Race Type',
#        'Race Primary Election Date', 'Primary Status', 'Primary Runoff Status',
#        'General Status', 'Partisan Lean', 'Primary %', 'Won Primary', 'Race',
#        'Veteran?', 'LGBTQ?', 'Elected Official?', 'Self-Funder?', 'STEM?',
#        'Obama Alum?', 'Party Support?', 'Emily Endorsed?',
#        'Gun Sense Candidate?', 'Biden Endorsed?', 'Warren Endorsed?',
#        'Sanders Endorsed?', 'Our Revolution Endorsed?',
#        'Justice Dems Endorsed?', 'PCCC Endorsed?', 'Indivisible Endorsed?',
#        'WFP Endorsed?', 'VoteVets Endorsed?', 'No Labels Support?',
#        'total_runners', 'Total Endorsements', 'Endorsed', 'receipts'],
#       dtype='object')

# %%
brookings = brookings[brookings['Candidate.Party'] == 'Democrat']
brookings = brookings[brookings['Incumbent'] != 'Candidate is an incumbent Member of Congress'].drop(
            columns=['Unnamed: 0', 'Incumbent', 'Candidate.Party', 'Candidate.Website.URL', 'Freshman.Member', 'Trump.Mention', 'Obama.Mention', 'Sanders.Mention', 
                    'Clinton.Mention', 'Special.Counsel.Mention', 'Travel.Ban.Mention', 'Primary.Outcome', 'Primary.Runoff.Outcome', 'Listed.military.service.'], inplace=False)
brookings
# Out:
#      Candidate.First.Name Candidate.Last.Name Candidate.State  \
# 0                   CAROL              HAFNER              AK
# 1             CHRISTOPHER             CUMINGS              AK
# 2                 DIMITRI               SHEIN              AK
# 3                   ALYSE              GALVIN              AK
# 7                 LIZETTA           MCCONNELL              AL
# ...                   ...                 ...             ...
# 2259                 PAUL               DAVIS              WV
# 2260              RICHARD               OJEDA              WV
# 2268                 GARY             TRAUNER              WY
# 2275               TRAVIS                HELM              WY
# 2276                 GREG              HUNTER              WY
#
#       Candidate.District Candidate.Gender                        Education  \
# 0                      1           Female                Bachelor's Degree
# 1                      1             Male  No Education Information Listed
# 2                      1             Male                Bachelor's Degree
# 3                      1           Female                Bachelor's Degree
# 7                      1           Female                            Other
# ...                  ...              ...                              ...
# 2259                   3             Male   Master's Degree (includes MBA)
# 2260                   3             Male                Bachelor's Degree
# 2268                   0             Male   Master's Degree (includes MBA)
# 2275                   1             Male                             J.D.
# 2276                   1             Male                Bachelor's Degree
#
#       Marital.Status                      Previous.Electoral.Experience  \
# 0     No information                                                NaN
# 1     No information                                                NaN
# 2            Married                                                NaN
# 3            Married                                                NaN
# 7            Married                                                NaN
# ...              ...                                                ...
# 2259         Married                                                NaN
# 2260         Married  Candidate mentions previous elected office exp...
# 2268         Married                                                NaN
# 2275  No information                                                NaN
# 2276  No information                                                NaN
#
#             Position.on.Affordable.Care.Act..ObamaCare.  \
# 0     Candidate provides complicated/complex/unclear...
# 1     Candidate provides complicated/complex/unclear...
# 2     Candidate provides complicated/complex/unclear...
# 3     Candidate provides complicated/complex/unclear...
# 7                     Candidate provides no information
# ...                                                 ...
# 2259                  Candidate provides no information
# 2260  Candidate provides complicated/complex/unclear...
# 2268  Candidate provides complicated/complex/unclear...
# 2275  Candidate provides complicated/complex/unclear...
# 2276  Candidate provides complicated/complex/unclear...
#
#                          Position.on.Minimum.Wage  ...  \
# 0               Candidate provides no information  ...
# 1               Candidate provides no information  ...
# 2               Candidate provides no information  ...
# 3     Candidate supports raising the minimum wage  ...
# 7               Candidate provides no information  ...
# ...                                           ...  ...
# 2259            Candidate provides no information  ...
# 2260            Candidate provides no information  ...
# 2268            Candidate provides no information  ...
# 2275            Candidate provides no information  ...
# 2276            Candidate provides no information  ...
#
#                            Position.on.Defense.Spending  \
# 0                     Candidate provides no information
# 1                     Candidate provides no information
# 2                     Candidate provides no information
# 3     Candidate provides complicated/complex/unclear...
# 7                     Candidate provides no information
# ...                                                 ...
# 2259                  Candidate provides no information
# 2260  Candidate opposes reductions in military spending
# 2268                  Candidate provides no information
# 2275                  Candidate provides no information
# 2276                  Candidate provides no information
#
#                   Position.on.Handling.Terrorism.Abroad  \
# 0                     Candidate provides no information
# 1                     Candidate provides no information
# 2                     Candidate provides no information
# 3                     Candidate provides no information
# 7                     Candidate provides no information
# ...                                                 ...
# 2259                  Candidate provides no information
# 2260  Candidate supports calls for increased America...
# 2268                  Candidate provides no information
# 2275                  Candidate provides no information
# 2276  Candidate provides complicated/complex/unclear...
#
#                      Position.on.Russia          Party.Category  \
# 0     Candidate provides no information    Progressive Democrat
# 1     Candidate provides no information                   Other
# 2     Candidate provides no information    Progressive Democrat
# 3     Candidate provides no information  Establishment Democrat
# 7     Candidate provides no information  Establishment Democrat
# ...                                 ...                     ...
# 2259  Candidate provides no information  Establishment Democrat
# 2260  Candidate provides no information  Establishment Democrat
# 2268  Candidate provides no information  Establishment Democrat
# 2275  Candidate provides no information       Moderate Democrat
# 2276  Candidate provides no information  Establishment Democrat
#
#      Party.Category.1 Incumbency Female Democrat Republican  \
# 0                 NaN          0    1.0        1          0
# 1                 NaN          0    0.0        1          0
# 2                 NaN          0    0.0        1          0
# 3                 NaN          0    1.0        1          0
# 7                 NaN          0    1.0        1          0
# ...               ...        ...    ...      ...        ...
# 2259              NaN          0    0.0        1          0
# 2260              NaN          0    0.0        1          0
# 2268              NaN          0    0.0        1          0
# 2275              NaN          0    0.0        1          0
# 2276              NaN          0    0.0        1          0
#
#                                             SinglePayer
# 0     Yes, candidate supports universal healthcare r...
# 1     Yes, candidate supports universal healthcare r...
# 2     Yes, candidate supports universal healthcare r...
# 3                                                   NaN
# 7                                                   NaN
# ...                                                 ...
# 2259                                                NaN
# 2260                                                NaN
# 2268                                                NaN
# 2275  Yes, candidate supports universal healthcare r...
# 2276  Yes, candidate supports universal healthcare r...
#
# [973 rows x 33 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
brookings['firstlast'] = (brookings['Candidate.First.Name'].str.lower() + ' ' + brookings['Candidate.Last.Name'].str.lower()).str.replace('.', '', regex=True).str.replace("\'", '', regex=True).str.replace('-', '', regex=True)
merged['lw_Candidate'] = merged['Candidate'].str.lower().str.replace('.', '', regex=True).str.replace("\'", '', regex=True).str.replace('-', '', regex=True)

final_merge = fuzzy_merge(merged, brookings, 'lw_Candidate', 'firstlast', threshold=70, limit=2)
final_merge.loc[170, 'matches'] = 'jasen lave'
final_merge.loc[234, 'matches'] = 'zigmond zozicki'
final_merge.loc[246, 'matches'] = 'william haas'
final_merge.loc[269, 'matches'] = 'd donaldson'
final_merge.loc[350, 'matches'] = 'liubov shirley'
final_merge.loc[424, 'matches'] = 'james crary'
final_merge.loc[484, 'matches'] = 'william hopkins'
final_merge.loc[509, 'matches'] = 'tawana waltercadien'
final_merge.loc[524, 'matches'] = 'j jones'
final_merge.loc[545, 'matches'] = 'edward allen'
final_merge = final_merge.drop(index=529, inplace=False).reset_index().drop(columns=['index'], inplace=False)

# %%
all_merged = pd.merge(final_merge, brookings, how='left', left_on='matches', right_on='firstlast')

# %%
len(all_merged)
# Out:
# 634

# %%
all_merged[all_merged['firstlast'] == 'jim gray']
# Out:
#     Candidate State                        District     Office Type Race Type  \
# 197  Jim Gray    KY  U.S. House Kentucky District 6  Representative   Regular
#
#     Race Primary Election Date  Primary Status Primary Runoff Status  \
# 197                    5/22/18               0                  None
#
#     General Status  Partisan Lean  ...  Trump.Mention  Obama.Mention  \
# 197           None         -17.41  ...     NO MENTION     NO MENTION
#
#      Sanders.Mention  Clinton.Mention  Special.Counsel.Mention  \
# 197       NO MENTION       NO MENTION               NO MENTION
#
#      Travel.Ban.Mention  SinglePayer  Primary.Outcome Primary.Runoff.Outcome  \
# 197          NO MENTION          NaN            Loser                    NaN
#
#      firstlast
# 197   jim gray
#
# [1 rows x 86 columns]

# %%
# function for estimating treatment effect
def estimate_treatment_effect(model, X, Y, Z):
    return np.mean((Z * Y / model.predict_proba(X)[:, 1]) - ((1 - Z) * Y / model.predict_proba(X)[:, 0]))

# %% [markdown]
# ## Inverse Propensity Weighting: Party Support
# - Y (outcome): `'Won Primary'`
# - Z (treatment): `'Party Support?'`
# - X (confounders): `'Total Other Endorsements'`, `'Partisan Lean'`, `'Race'`, `'Veteran?'`, `'LGBTQ?'`, `'STEM?'`, `'Elected Official?'`, `'receipts'`

# %%
party = merged[merged['Party Support?'].notnull() == True][['Won Primary', 'Party Support?', 'Total Endorsements', 'Partisan Lean', 'Race', 'Veteran?', 'LGBTQ?', 'STEM?', 'Elected Official?', 'receipts']].reset_index().drop(columns=['index']).dropna()
party['Total Other Endorsements'] = party['Total Endorsements'] - party['Party Support?']
party = party.drop(columns=['Total Endorsements'])[party['receipts'].notnull()]
party.head()
# Out:
#    Won Primary  Party Support?  Partisan Lean  Race  Veteran?  LGBTQ?  STEM?  \
# 0            1             1.0         -13.51     0         0       0      0
# 1            0             0.0         -13.51     0         1       0      0
# 2            0             0.0         -13.51     1         0       0      0
# 3            0             0.0         -13.51     0         0       0      0
# 4            0             0.0           0.62     0         0       0      1
#
#    Elected Official?    receipts  Total Other Endorsements
# 0                  1  2366991.03                       1.0
# 1                  0    33934.76                       1.0
# 2                  0    34466.05                       0.0
# 3                  0   270092.89                       0.0
# 4                  0    68767.16                       2.0

# %%
# creating our treatment, outcome, and confounder arrays
Z = party['Party Support?'].values
Y = party['Won Primary'].values
X = party.drop(['Party Support?', 'Won Primary'], axis=1).to_numpy()

# getting propensity scores through logistic regression
lr = LR(penalty='none', max_iter=200, random_state=0)
fit = lr.fit(X, Z)

estimate_treatment_effect(fit, X, Y, Z)
# Out:
# 0.22853389931489862

# %%
# the naive estimator does not account for confounders!
np.mean(Y[Z == 1] * Z[Z == 1]) - np.mean(Y[Z == 0] * (1 - Z[Z == 0]))
# Out:
# 0.9014184397163121

# %% [markdown]
# ### Adding the propensity scores

# %%
party['pscore'] = fit.predict_proba(X)[:, 1]
party.head()
# Out:
#    Won Primary  Party Support?  Partisan Lean  Race  Veteran?  LGBTQ?  STEM?  \
# 0            1             1.0         -13.51     0         0       0      0
# 1            0             0.0         -13.51     0         1       0      0
# 2            0             0.0         -13.51     1         0       0      0
# 3            0             0.0         -13.51     0         0       0      0
# 4            0             0.0           0.62     0         0       0      1
#
#    Elected Official?    receipts  Total Other Endorsements    pscore
# 0                  1  2366991.03                       1.0  0.634807
# 1                  0    33934.76                       1.0  0.501982
# 2                  0    34466.05                       0.0  0.502013
# 3                  0   270092.89                       0.0  0.515767
# 4                  0    68767.16                       2.0  0.504016

# %%
plt.hist(party[party['Party Support?'] == 1]['pscore']);
plt.title("Propensity score of people receiving the treatment (Party Support)")
plt.savefig('party_support_treat.png');

# %%
plt.hist(party[party['Party Support?'] == 0]['pscore']);
plt.title("Propensity score of people not receiving the treatment")
plt.savefig('party_support_ctrl.png');

# %% [markdown]
# ### IPW Estimate

# %%
reweighted_treated = (party[party['Party Support?'] == 1]['Won Primary'] / party[party['Party Support?'] == 1]['pscore']).sum()
reweighted_control = (party[party['Party Support?'] == 0]['Won Primary'] / (1 - party[party['Party Support?'] == 0]['pscore'])).sum()
ipw_estimate = (reweighted_treated - reweighted_control) / len(party)
print('IPW estimate:', ipw_estimate)

obs_filt = party[party['pscore'].between(0.1, 0.9)]
reweighted_treated_filt = (obs_filt[obs_filt['Party Support?'] == 1]['Won Primary'] / obs_filt[obs_filt['Party Support?'] == 1]['pscore']).sum()
reweighted_control_filt = (obs_filt[obs_filt['Party Support?'] == 0]['Won Primary'] / (1 - obs_filt[obs_filt['Party Support?'] == 0]['pscore'])).sum()
trimmed_ipw_estimate = (reweighted_treated_filt - reweighted_control_filt) / len(obs_filt)
print('trimmed IPW estimate:', trimmed_ipw_estimate)
# Out:
# IPW estimate: 0.22853389931489862
# trimmed IPW estimate: 0.2217985299710571

# %% [markdown]
# ## Inverse Propensity Weighting: Our Revolution
# - Y (outcome): `'Won Primary'`
# - Z (treatment): `'Our Revolution Endorsed?'`
# - X (confounders): `'Total Other Endorsements'`, `'Partisan Lean'`, `'Race'`, `'Veteran?'`, `'LGBTQ?'`, `'STEM?'`, `'Elected Official?'`, `'receipts'`

# %%
our_rev = merged[merged['Our Revolution Endorsed?'].notnull() == True][['Won Primary', 'Our Revolution Endorsed?', 'Total Endorsements', 'Partisan Lean', 'Race', 'Veteran?', 'LGBTQ?', 'STEM?', 'Elected Official?', 'receipts']].reset_index().drop(columns=['index']).dropna()
our_rev['Total Other Endorsements'] = our_rev['Total Endorsements'] - our_rev['Our Revolution Endorsed?']
our_rev = our_rev.drop(columns=['Total Endorsements'])[our_rev['receipts'].notnull()]
our_rev.head()
# Out:
#    Won Primary  Our Revolution Endorsed?  Partisan Lean  Race  Veteran?  \
# 0            1                       1.0     -21.379999     0         0
# 1            0                       0.0     -21.379999     0         0
# 2            0                       0.0     -21.379999     0         0
# 3            0                       0.0     -21.379999     0         0
# 4            0                       1.0       0.620000     0         0
#
#    LGBTQ?  STEM?  Elected Official?    receipts  Total Other Endorsements
# 0       0      0                  0  1097584.95                       1.0
# 1       0      0                  0    17275.00                       0.0
# 2       0      0                  0   290020.57                       0.0
# 3       0      0                  0    68655.53                       1.0
# 4       0      1                  0    68767.16                       1.0

# %%
# creating our treatment, outcome, and confounder arrays
Z = our_rev['Our Revolution Endorsed?'].values
Y = our_rev['Won Primary'].values
X = our_rev.drop(['Our Revolution Endorsed?', 'Won Primary'], axis=1).to_numpy()

# getting propensity scores through logistic regression
lr = LR(penalty='none', max_iter=200, random_state=0)
fit = lr.fit(X, Z)

estimate_treatment_effect(fit, X, Y, Z)
# Out:
# 0.09643207821222963

# %% [markdown]
# Since this is a negative number, the treatment (being endorsed by `Our Revolution`) caused the probability of winning to decrease.

# %%
# naive estimator from HW4, not sure if we need for this
# the naive estimator does not account for confounders!
# Interesting... once we control for confounders, we observe the opposite effect (positive to negative)
np.mean(Y[Z == 1] * Z[Z == 1]) - np.mean(Y[Z == 0] * (1 - Z[Z == 0]))
# Out:
# 0.08556231003039513

# %% [markdown]
# ### Adding the propensity scores

# %%
our_rev['pscore'] = fit.predict_proba(X)[:, 1]
our_rev.head()
# Out:
#    Won Primary  Our Revolution Endorsed?  Partisan Lean  Race  Veteran?  \
# 0            1                       1.0     -21.379999     0         0
# 1            0                       0.0     -21.379999     0         0
# 2            0                       0.0     -21.379999     0         0
# 3            0                       0.0     -21.379999     0         0
# 4            0                       1.0       0.620000     0         0
#
#    LGBTQ?  STEM?  Elected Official?    receipts  Total Other Endorsements  \
# 0       0      0                  0  1097584.95                       1.0
# 1       0      0                  0    17275.00                       0.0
# 2       0      0                  0   290020.57                       0.0
# 3       0      0                  0    68655.53                       1.0
# 4       0      1                  0    68767.16                       1.0
#
#      pscore
# 0  0.374233
# 1  0.497977
# 2  0.466091
# 3  0.491961
# 4  0.491948

# %%
plt.hist(our_rev[our_rev['Our Revolution Endorsed?'] == 1]['pscore'])
plt.title("Propensity score of people receiving the treatment\n(Our Revolution Endorsement)")
plt.savefig('our_rev_treat.png');

# %%
plt.hist(our_rev[our_rev['Our Revolution Endorsed?'] == 0]['pscore'])
plt.title("Propensity score of people not receiving the treatment")
plt.savefig('our_rev_ctrl.png');

# %% [markdown]
# ### IPW Estimate

# %%
reweighted_treated = (our_rev[our_rev['Our Revolution Endorsed?'] == 1]['Won Primary'] / our_rev[our_rev['Our Revolution Endorsed?'] == 1]['pscore']).sum()
reweighted_control = (our_rev[our_rev['Our Revolution Endorsed?'] == 0]['Won Primary'] / (1 - our_rev[our_rev['Our Revolution Endorsed?'] == 0]['pscore'])).sum()
ipw_estimate = (reweighted_treated - reweighted_control) / len(our_rev)
print('IPW estimate:', ipw_estimate)

obs_filt = our_rev[our_rev['pscore'].between(0.1, 0.9)]
reweighted_treated_filt = (obs_filt[obs_filt['Our Revolution Endorsed?'] == 1]['Won Primary'] / obs_filt[obs_filt['Our Revolution Endorsed?'] == 1]['pscore']).sum()
reweighted_control_filt = (obs_filt[obs_filt['Our Revolution Endorsed?'] == 0]['Won Primary'] / (1 - obs_filt[obs_filt['Our Revolution Endorsed?'] == 0]['pscore'])).sum()
trimmed_ipw_estimate = (reweighted_treated_filt - reweighted_control_filt) / len(obs_filt)
print('trimmed IPW estimate:', trimmed_ipw_estimate)
# Out:
# IPW estimate: 0.09643207821222961
# trimmed IPW estimate: 0.05568433328834726

# %% [markdown]
# ## Inverse Propensity Weighting: Emily's List
# - Y (outcome): `'Won Primary'`
# - Z (treatment): `'Emily Endorsed?'`
# - X (confounders): `'Total Other Endorsements'`, `'Partisan Lean'`, `'Race'`, `'Veteran?'`, `'LGBTQ?'`, `'STEM?'`, `'Elected Official?'`, `'receipts'`

# %%
emily = merged[merged['Emily Endorsed?'].notnull() == True][['Won Primary', 'Emily Endorsed?', 'Total Endorsements', 'Partisan Lean', 'Race', 'Veteran?', 'LGBTQ?', 'STEM?', 'Elected Official?', 'receipts']].reset_index().drop(columns=['index'])
emily['Total Other Endorsements'] = emily['Total Endorsements'] - emily['Emily Endorsed?']
emily = emily.drop(columns=['Total Endorsements'])[emily['receipts'].notnull()]
emily.head()
# Out:
#    Won Primary  Emily Endorsed?  Partisan Lean  Race  Veteran?  LGBTQ?  STEM?  \
# 0            0              0.0           0.62     0         0       0      1
# 1            1              0.0           0.62     0         0       0      1
# 2            0              0.0           0.62     0         0       0      0
# 3            0              0.0           0.62     0         1       0      1
# 4            0              0.0           0.62     0         0       0      1
#
#    Elected Official?    receipts  Total Other Endorsements
# 0                  0    68767.16                       2.0
# 1                  0  8441529.09                       2.0
# 2                  0   346820.52                       0.0
# 3                  0    48734.30                       0.0
# 4                  1   840266.61                       0.0

# %%
# creating our treatment, outcome, and confounder arrays
Z = emily['Emily Endorsed?'].values
Y = emily['Won Primary'].values
X = emily.drop(['Emily Endorsed?', 'Won Primary'], axis=1).to_numpy()

# getting propensity scores through logistic regression
lr = LR(penalty='none', max_iter=200, random_state=0)
fit = lr.fit(X, Z)

estimate_treatment_effect(fit, X, Y, Z)
# Out:
# 0.20195515235529135

# %%
# the naive estimator does not account for confounders!
np.mean(Y[Z == 1] * Z[Z == 1]) - np.mean(Y[Z == 0] * (1 - Z[Z == 0]))
# Out:
# 0.6101842196732707

# %% [markdown]
# ### Adding the propensity scores

# %%
emily['pscore'] = fit.predict_proba(X)[:, 1]
emily.head()
# Out:
#    Won Primary  Emily Endorsed?  Partisan Lean  Race  Veteran?  LGBTQ?  STEM?  \
# 0            0              0.0           0.62     0         0       0      1
# 1            1              0.0           0.62     0         0       0      1
# 2            0              0.0           0.62     0         0       0      0
# 3            0              0.0           0.62     0         1       0      1
# 4            0              0.0           0.62     0         0       0      1
#
#    Elected Official?    receipts  Total Other Endorsements    pscore
# 0                  0    68767.16                       2.0  0.499988
# 1                  0  8441529.09                       2.0  0.498499
# 2                  0   346820.52                       0.0  0.499938
# 3                  0    48734.30                       0.0  0.499991
# 4                  1   840266.61                       0.0  0.499851

# %%
plt.hist(emily[emily['Emily Endorsed?'] == 1]['pscore'])
plt.title("Propensity score of people receiving the treatment\n(Emily Endorsed)")
plt.savefig('emily_treat.png');

# %%
plt.hist(emily[emily['Emily Endorsed?'] == 0]['pscore'])
plt.title("Propensity score of people not receiving the treatment")
plt.savefig('emily_ctrl.png');

# %% [markdown]
# ### IPW Estimate

# %%
reweighted_treated = (emily[emily['Emily Endorsed?'] == 1]['Won Primary'] / emily[emily['Emily Endorsed?'] == 1]['pscore']).sum()
reweighted_control = (emily[emily['Emily Endorsed?'] == 0]['Won Primary'] / (1 - emily[emily['Emily Endorsed?'] == 0]['pscore'])).sum()
ipw_estimate = (reweighted_treated - reweighted_control) / len(emily)
print('IPW estimate:', ipw_estimate)

obs_filt = emily[emily['pscore'].between(0.1, 0.9)]
reweighted_treated_filt = (obs_filt[obs_filt['Emily Endorsed?'] == 1]['Won Primary'] / obs_filt[obs_filt['Emily Endorsed?'] == 1]['pscore']).sum()
reweighted_control_filt = (obs_filt[obs_filt['Emily Endorsed?'] == 0]['Won Primary'] / (1 - obs_filt[obs_filt['Emily Endorsed?'] == 0]['pscore'])).sum()
trimmed_ipw_estimate = (reweighted_treated_filt - reweighted_control_filt) / len(obs_filt)
print('trimmed IPW estimate:', trimmed_ipw_estimate)
# Out:
# IPW estimate: 0.20195515235529135
# trimmed IPW estimate: 0.20195515235529135

# %% [markdown]
# ## Inverse Propensity Weighting: Justice Dems
# - Y (outcome): `'Won Primary'`
# - Z (treatment): `'Justice Dems Endorsed?'`
# - X (confounders): `'Total Endorsements'`, `'Partisan Lean'`, `'Race'`, `'Veteran?'`, `'LGBTQ?'`, `'STEM?'`, `'Elected Official?'`, `'receipts'`

# %%
jd = merged[merged['Justice Dems Endorsed?'].notnull() == True][['Won Primary', 'Justice Dems Endorsed?', 'Total Endorsements', 'Partisan Lean', 'Race', 'Veteran?', 'LGBTQ?', 'STEM?', 'Elected Official?', 'receipts']].reset_index().drop(columns=['index'])
jd['Total Other Endorsements'] = jd['Total Endorsements'] - jd['Justice Dems Endorsed?']
jd = jd.drop(columns=['Total Endorsements'])[jd['receipts'].notnull()]
jd.head()
# Out:
#    Won Primary  Justice Dems Endorsed?  Partisan Lean  Race  Veteran?  LGBTQ?  \
# 0            1                     1.0     -21.379999     0         0       0
# 1            0                     0.0     -21.379999     0         0       0
# 2            0                     0.0     -21.379999     0         0       0
# 3            0                     0.0     -21.379999     0         0       0
# 4            0                     1.0       0.620000     0         0       0
#
#    STEM?  Elected Official?    receipts  Total Other Endorsements
# 0      0                  0  1097584.95                       1.0
# 1      0                  0    17275.00                       0.0
# 2      0                  0   290020.57                       0.0
# 3      0                  0    68655.53                       1.0
# 4      1                  0    68767.16                       1.0

# %%
# creating our treatment, outcome, and confounder arrays
Z = jd['Justice Dems Endorsed?'].values
Y = jd['Won Primary'].values
X = jd.drop(['Justice Dems Endorsed?', 'Won Primary'], axis=1).to_numpy()

# getting propensity scores through logistic regression
lr = LR(penalty='none', max_iter=200, random_state=0)
fit = lr.fit(X, Z)

estimate_treatment_effect(fit, X, Y, Z)
# Out:
# 0.10498301473032351

# %%
# the naive estimator does not account for confounders!
np.mean(Y[Z == 1] * Z[Z == 1]) - np.mean(Y[Z == 0] * (1 - Z[Z == 0]))
# Out:
# 0.03787878787878787

# %% [markdown]
# ### Adding the propensity scores

# %%
jd['pscore'] = fit.predict_proba(X)[:, 1]
jd.head()
# Out:
#    Won Primary  Justice Dems Endorsed?  Partisan Lean  Race  Veteran?  LGBTQ?  \
# 0            1                     1.0     -21.379999     0         0       0
# 1            0                     0.0     -21.379999     0         0       0
# 2            0                     0.0     -21.379999     0         0       0
# 3            0                     0.0     -21.379999     0         0       0
# 4            0                     1.0       0.620000     0         0       0
#
#    STEM?  Elected Official?    receipts  Total Other Endorsements    pscore
# 0      0                  0  1097584.95                       1.0  0.310410
# 1      0                  0    17275.00                       0.0  0.496859
# 2      0                  0   290020.57                       0.0  0.447466
# 3      0                  0    68655.53                       1.0  0.487520
# 4      1                  0    68767.16                       1.0  0.487500

# %%
plt.hist(jd[jd['Justice Dems Endorsed?'] == 1]['pscore'])
plt.title("Propensity score of people receiving the treatment\n(Justice Dems Endorsed)")
plt.savefig('justice_dems_treat.png');

# %%
plt.hist(jd[jd['Justice Dems Endorsed?'] == 0]['pscore'])
plt.title("Propensity score of people not receiving the treatment")
plt.savefig('justice_dems_ctrl.png');

# %% [markdown]
# ### IPW Estimate

# %%
reweighted_treated = (jd[jd['Justice Dems Endorsed?'] == 1]['Won Primary'] / jd[jd['Justice Dems Endorsed?'] == 1]['pscore']).sum()
reweighted_control = (jd[jd['Justice Dems Endorsed?'] == 0]['Won Primary'] / (1 - jd[jd['Justice Dems Endorsed?'] == 0]['pscore'])).sum()
ipw_estimate = (reweighted_treated - reweighted_control) / len(jd)
print('IPW estimate:', ipw_estimate)

obs_filt = jd[jd['pscore'].between(0.1, 0.9)]
reweighted_treated_filt = (obs_filt[obs_filt['Justice Dems Endorsed?'] == 1]['Won Primary'] / obs_filt[obs_filt['Justice Dems Endorsed?'] == 1]['pscore']).sum()
reweighted_control_filt = (obs_filt[obs_filt['Justice Dems Endorsed?'] == 0]['Won Primary'] / (1 - obs_filt[obs_filt['Justice Dems Endorsed?'] == 0]['pscore'])).sum()
trimmed_ipw_estimate = (reweighted_treated_filt - reweighted_control_filt) / len(obs_filt)
print('trimmed IPW estimate:', trimmed_ipw_estimate)
# Out:
# IPW estimate: 0.10498301473032351
# trimmed IPW estimate: 0.09851099666720017

# %% [markdown]
# ## Inverse Propensity Weighting: Gun Sense
# - Y (outcome): `'Won Primary'`
# - Z (treatment): `'Gun Sense Candidate?'`
# - X (confounders): `'Total Endorsements'`, `'Partisan Lean'`, `'Race'`, `'Veteran?'`, `'LGBTQ?'`, `'STEM?'`, `'Elected Official?'`, `'receipts'`

# %%
gs = merged[merged['Gun Sense Candidate?'].notnull() == True][['Won Primary', 'Gun Sense Candidate?', 'Total Endorsements', 'Partisan Lean', 'Race', 'Veteran?', 'LGBTQ?', 'STEM?', 'Elected Official?', 'receipts']].reset_index().drop(columns=['index'])
gs['Total Other Endorsements'] = gs['Total Endorsements'] - gs['Gun Sense Candidate?']
gs = gs.drop(columns=['Total Endorsements'])[gs['receipts'].notnull()]
gs.head()
# Out:
#    Won Primary  Gun Sense Candidate?  Partisan Lean  Race  Veteran?  LGBTQ?  \
# 0            0                   1.0         -33.66     1         0       0
# 1            1                   1.0         -33.66     0         0       0
# 2            1                   1.0         -62.48     0         0       0
# 3            0                   0.0         -62.48     0         1       0
# 4            1                   1.0         -13.51     0         0       0
#
#    STEM?  Elected Official?    receipts  Total Other Endorsements
# 0      1                  0    14535.25                       0.0
# 1      0                  0   467514.71                       0.0
# 2      0                  0    70425.87                       0.0
# 3      0                  0    21088.35                       0.0
# 4      0                  1  2366991.03                       1.0

# %%
# creating our treatment, outcome, and confounder arrays
Z = gs['Gun Sense Candidate?'].values
Y = gs['Won Primary'].values
X = gs.drop(['Gun Sense Candidate?', 'Won Primary'], axis=1).to_numpy()

# getting propensity scores through logistic regression
lr = LR(penalty='none', max_iter=200, random_state=0)
fit = lr.fit(X, Z)

estimate_treatment_effect(fit, X, Y, Z)
# Out:
# 0.13881062411013584

# %%
# the naive estimator does not account for confounders!
np.mean(Y[Z == 1] * Z[Z == 1]) - np.mean(Y[Z == 0] * (1 - Z[Z == 0]))
# Out:
# 0.3217761557177616

# %% [markdown]
# ### Adding the propensity scores

# %%
gs['pscore'] = fit.predict_proba(X)[:, 1]
gs.head()
# Out:
#    Won Primary  Gun Sense Candidate?  Partisan Lean  Race  Veteran?  LGBTQ?  \
# 0            0                   1.0         -33.66     1         0       0
# 1            1                   1.0         -33.66     0         0       0
# 2            1                   1.0         -62.48     0         0       0
# 3            0                   0.0         -62.48     0         1       0
# 4            1                   1.0         -13.51     0         0       0
#
#    STEM?  Elected Official?    receipts  Total Other Endorsements    pscore
# 0      1                  0    14535.25                       0.0  0.501378
# 1      0                  0   467514.71                       0.0  0.544193
# 2      0                  0    70425.87                       0.0  0.506674
# 3      0                  0    21088.35                       0.0  0.501999
# 4      0                  1  2366991.03                       1.0  0.710401

# %%
plt.hist(gs[gs['Gun Sense Candidate?'] == 1]['pscore'])
plt.title("Propensity score of people receiving the treatment\n(Gun Sense Candidate)")
plt.savefig('gun_sense_treat.png');

# %%
plt.hist(gs[gs['Gun Sense Candidate?'] == 0]['pscore'])
plt.title("Propensity score of people not receiving the treatment")
plt.savefig('gun_sense_ctrl.png');

# %% [markdown]
# ### IPW Estimate

# %%
reweighted_treated = (gs[gs['Gun Sense Candidate?'] == 1]['Won Primary'] / gs[gs['Gun Sense Candidate?'] == 1]['pscore']).sum()
reweighted_control = (gs[gs['Gun Sense Candidate?'] == 0]['Won Primary'] / (1 - gs[gs['Gun Sense Candidate?'] == 0]['pscore'])).sum()
ipw_estimate = (reweighted_treated - reweighted_control) / len(gs)
print('IPW estimate:', ipw_estimate)

obs_filt = gs[gs['pscore'].between(0.1, 0.9)]
reweighted_treated_filt = (obs_filt[obs_filt['Gun Sense Candidate?'] == 1]['Won Primary'] / obs_filt[obs_filt['Gun Sense Candidate?'] == 1]['pscore']).sum()
reweighted_control_filt = (obs_filt[obs_filt['Gun Sense Candidate?'] == 0]['Won Primary'] / (1 - obs_filt[obs_filt['Gun Sense Candidate?'] == 0]['pscore'])).sum()
trimmed_ipw_estimate = (reweighted_treated_filt - reweighted_control_filt) / len(obs_filt)
print('trimmed IPW estimate:', trimmed_ipw_estimate)
# Out:
# IPW estimate: 0.13881062411013584
# trimmed IPW estimate: 0.08960197814165571

# %% [markdown]
# ## Bootstrapping ATE estimates

# %%
#TODO: Fill in the missing values
def draw_tau_hat(data=obs, random_state=None):
    """Returns a single bootstrapped estimate of the ATE.
    
    Inputs:
        data: DataFrame of observed data
        random_state: integer to help standardize sampling output 
        for grading and troubleshooting purposes
    Output:
        float, estimated average treatment effect
    """
    sample = data.sample(frac=1, replace=True, random_state=random_state)
    fit_model = fit_OLS_model(sample, 'outcome', ['treat', 'age', 'educ', 'black', 'hisp', 'marr', 'nodegree'])
    estimated_ate = fit_model.params['treat']
    return estimated_ate

def get_bootstrapped_ate(data=obs, n=1000):
    """Returns n bootstrapped estimates of the ATE.
    
    Inputs:
        data: DataFrame of observed data
        n: number of bootstrapped estimates we would like to return
    Output:
        list of estimated average treatment effects
    """
    estimates = []
    for i in np.arange(n):
        estimates.append(draw_tau_hat(data))
    return estimates
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [72], in <cell line: 2>()
#       1 #TODO: Fill in the missing values
# ----> 2 def draw_tau_hat(data=obs, random_state=None):
#       3     """Returns a single bootstrapped estimate of the ATE.
#       4
#       5     Inputs:
#    (...)
#      10         float, estimated average treatment effect
#      11     """
#      12     sample = data.sample(frac=1, replace=True, random_state=random_state)
#
# NameError: name 'obs' is not defined
